# %%
import requests
import pandas
from datetime import datetime, timedelta

# %%
BASE_URL = "https://api.github.com"
owner = "cdbustamantep"
repo = "interview"
# Construct the URL to get pull requests
url = f"{BASE_URL}/repos/{owner}/{repo}/pulls"
# Set up parameters to filter pull requests by date
since_date = (datetime.now() - timedelta(days=7)).isoformat()
params = {"state": "all", "since": since_date}

# Make a GET request to the GitHub API
response = requests.get(url, params=params)
response.json()
print(response.text)
# Out:
# [{"url":"https://api.github.com/repos/cdbustamantep/interview/pulls/2","id":1690867871,"node_id":"PR_kwDOLISBBs5kyJif","html_url":"https://github.com/cdbustamantep/interview/pull/2","diff_url":"https://github.com/cdbustamantep/interview/pull/2.diff","patch_url":"https://github.com/cdbustamantep/interview/pull/2.patch","issue_url":"https://api.github.com/repos/cdbustamantep/interview/issues/2","number":2,"state":"closed","locked":false,"title":"adding code","user":{"login":"cdbustamantep","id":75045922,"node_id":"MDQ6VXNlcjc1MDQ1OTIy","avatar_url":"https://avatars.githubusercontent.com/u/75045922?v=4","gravatar_id":"","url":"https://api.github.com/users/cdbustamantep","html_url":"https://github.com/cdbustamantep","followers_url":"https://api.github.com/users/cdbustamantep/followers","following_url":"https://api.github.com/users/cdbustamantep/following{/other_user}","gists_url":"https://api.github.com/users/cdbustamantep/gists{/gist_id}","starred_url":"https://api.github.com/users/cdbustamantep/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/cdbustamantep/subscriptions","organizations_url":"https://api.github.com/users/cdbustamantep/orgs","repos_url":"https://api.github.com/users/cdbustamantep/repos","events_url":"https://api.github.com/users/cdbustamantep/events{/privacy}","received_events_url":"https://api.github.com/users/cdbustamantep/received_events","type":"User","site_admin":false},"body":null,"created_at":"2024-01-23T01:32:10Z","updated_at":"2024-01-23T01:32:17Z","closed_at":"2024-01-23T01:32:17Z","merged_at":"2024-01-23T01:32:17Z","merge_commit_sha":"c3a549c0dbff34e4d7f837838ec8fc9e7431b1ee","assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/cdbustamantep/interview/pulls/2/commits","review_comments_url":"https://api.github.com/repos/cdbustamantep/interview/pulls/2/comments","review_comment_url":"https://api.github.com/repos/cdbustamantep/interview/pulls/comments{/number}","comments_url":"https://api.github.com/repos/cdbustamantep/interview/issues/2/comments","statuses_url":"https://api.github.com/repos/cdbustamantep/interview/statuses/e33406a981f87a55455da2e0c65032489e5d4b08","head":{"label":"cdbustamantep:second","ref":"second","sha":"e33406a981f87a55455da2e0c65032489e5d4b08","user":{"login":"cdbustamantep","id":75045922,"node_id":"MDQ6VXNlcjc1MDQ1OTIy","avatar_url":"https://avatars.githubusercontent.com/u/75045922?v=4","gravatar_id":"","url":"https://api.github.com/users/cdbustamantep","html_url":"https://github.com/cdbustamantep","followers_url":"https://api.github.com/users/cdbustamantep/followers","following_url":"https://api.github.com/users/cdbustamantep/following{/other_user}","gists_url":"https://api.github.com/users/cdbustamantep/gists{/gist_id}","starred_url":"https://api.github.com/users/cdbustamantep/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/cdbustamantep/subscriptions","organizations_url":"https://api.github.com/users/cdbustamantep/orgs","repos_url":"https://api.github.com/users/cdbustamantep/repos","events_url":"https://api.github.com/users/cdbustamantep/events{/privacy}","received_events_url":"https://api.github.com/users/cdbustamantep/received_events","type":"User","site_admin":false},"repo":{"id":746881286,"node_id":"R_kgDOLISBBg","name":"interview","full_name":"cdbustamantep/interview","private":false,"owner":{"login":"cdbustamantep","id":75045922,"node_id":"MDQ6VXNlcjc1MDQ1OTIy","avatar_url":"https://avatars.githubusercontent.com/u/75045922?v=4","gravatar_id":"","url":"https://api.github.com/users/cdbustamantep","html_url":"https://github.com/cdbustamantep","followers_url":"https://api.github.com/users/cdbustamantep/followers","following_url":"https://api.github.com/users/cdbustamantep/following{/other_user}","gists_url":"https://api.github.com/users/cdbustamantep/gists{/gist_id}","starred_url":"https://api.github.com/users/cdbustam ...
